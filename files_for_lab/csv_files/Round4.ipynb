# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df = pd.read_csv("marketing_customer_analysis.csv")

# %%
# We are using median to clean up the income column
#median_income = round(df["Income"].median(),2)
#print("Median Income is: ", median_income)

# %%
df["Income"] = df["Income"].replace(0, df[df["Income"] != 0]["Income"].median())

# %%
categorical_columns = data.select_dtypes(include='object')
categorical_columns

#for col in categorical_columns:
 #   unique_values = df[col].unique()
  #  print(f"Unique values for '{col}': {unique_values}")

numerical_columns = df.select_dtypes(include=[np.number])
#df.columns[df.dtypes != 'object']
#numerical_description = df[numerical_columns].describe()
numerical_columns.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 categorical_columns = data.select_dtypes(include='object')
#       2 categorical_columns
#       4 #for col in categorical_columns:
#       5  #   unique_values = df[col].unique()
#       6   #  print(f"Unique values for '{col}': {unique_values}")
#
# NameError: name 'data' is not defined

# %%
numerical_columns
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903   48081                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827   48081                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428   48081                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866   48081                    77
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
##Seaborn

# %%
for column in numerical_columns:
    sns.displot(df[column], bins=30)

plt.show()

# %%
for column in numerical_columns:
    plt.hist(df[column], bins=30)
             
plt.show()

# %%
#no, the distributions do not look like normal distributions

# %%
#Check for multicollinearity

# %%
correlations_matrix = numerical_columns.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
# None of the other features strongly correlates to each other. Therefore, they can all be included.
